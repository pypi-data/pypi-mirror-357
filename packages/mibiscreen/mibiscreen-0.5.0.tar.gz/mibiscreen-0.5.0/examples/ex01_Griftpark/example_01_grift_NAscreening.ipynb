# %% [markdown]
# # MiBiPreT example: NA screening using Griftpark data
#
# ## Background: Griftpark contaminant site
#
# Text to be added.
#
# ## Data Analysis
#
# Text to be added.

# %%
import mibiscreen as mbs

# %% [markdown]
# ### Data handling
#
# **Load in data:**
#
# Returns loaded data as DataFrame. Will be reported when verbose flag is `True`.

# %%
file_path = './grift_BTEXIIN.csv'
data_raw,units = mbs.load_csv(file_path,verbose=False)

# %% [markdown]
# **Standardization of input data:**
#
# Runs all checks on data, i.e. column names, units and values in one go and returns transformed data with standard column names and valueas in numerical type where possible. Data is reduced to those columns containing known quantities.

# %%
data,units = mbs.standardize(data_raw, reduce = True, verbose=False)
# Out:
# WARNING: Cound not transform 'sample_nr' to numerical values
# ________________________________________________________________
# WARNING: Cound not transform 'obs_well' to numerical values
# ________________________________________________________________
# WARNING: Cound not transform 'well_type' to numerical values
# ________________________________________________________________
# WARNING: Cound not transform 'depth' to numerical values
# ________________________________________________________________

# %% [markdown]
# ### Natural Attenuation (NA) Screening
#
# Performing NA screening step by step.

# %% [markdown]
# **Calculation of number of electrons for reduction**
#
# Returns pandas-Series with total amount of electron reductors per well in [mmol e-/l]:

# %%
tot_reduct = mbs.reductors(data,verbose = True,ea_group = 'ONSFe')
# Out:
# ==============================================================
#  Running function 'reductors()' on data
# ==============================================================
# Selecting specific group of geochemicals:
# O
# N
# S
# F
# e
# Selected set of quantities:
# iron2
# sulfate
# WARNING: quantities from name list not in data:
# nitrate
# oxygen
# Maybe data not in standardized format. Run 'standardize()' first.
# _________________________________________________________________
# Total amount of electron reductors per well in [mmol e-/l] is:
# 1     17.012271
# 2     13.866108
# 3      1.942974
# 4           NaN
# 5      0.092681
# 6      0.749220
# 7      0.416233
# 8      6.576483
# 9     10.600622
# 10    19.823788
# 11     3.303222
# 12    14.755178
# 13     3.552962
# 14     7.344570
# 15    11.340408
# 16    14.210188
# 17    11.822679
# 18    17.483449
# 19     0.915713
# 20          NaN
# 21     1.165453
# 22     0.851334
# 23     2.406377
# 24    21.861353
# 25     2.156417
# 26     0.056677
# Name: total_reductors, dtype: float64
# ----------------------------------------------------------------

# %% [markdown]
# **Calculation of number of electrons needed for oxidation**
#
# Returns pandas-Series with total amount of oxidators per well in [mmol e-/l]:

# %%
tot_oxi = mbs.oxidators(data,verbose = True, contaminant_group='BTEXIIN')
# Out:
# ==============================================================
#  Running function 'oxidators()' on data
# ==============================================================
# Selecting specific group of contaminants:
# B
# T
# E
# X
# I
# I
# N
# Selected set of quantities:
# indane
# naphthalene
# o_xylene
# benzene
# toluene
# ethylbenzene
# indene
# pm_xylene
# Total amount of oxidators per well in [mmol e-/l] is:
# 1     0.025176
# 2     0.044319
# 3     1.566300
# 4     3.700510
# 5     3.006575
# 6     2.096408
# 7     1.096832
# 8     0.610001
# 9     0.071837
# 10    0.009147
# 11    0.007641
# 12    3.388206
# 13    0.193936
# 14    3.509553
# 15    0.227017
# 16    0.008771
# 17    0.011823
# 18    0.044319
# 19    3.271534
# 20    4.455531
# 21    3.750462
# 22    3.185337
# 23    5.040701
# 24    0.081200
# 25    0.006903
# 26    0.010263
# Name: total_oxidators, dtype: float64
# -----------------------------------------------------

# %% [markdown]
# **Calculation of number of electron balance**
#
# Returns pandas-Series with ratio of reductors to oxidators. If value below 1, available electrons for reduction are not sufficient for reaction and thus NA is potentially not taking place.

# %%
e_bal = mbs.electron_balance(data,verbose = True)
# Out:
# ==============================================================
#  Running function 'electron_balance()' on data
# ==============================================================
# WARNING: quantities from name list not in data:
# nitrate
# oxygen
# Maybe data not in standardized format. Run 'standardize()' first.
# _________________________________________________________________
# Electron balance e_red/e_cont is:
# 1      671.244878
# 2      311.807766
# 3        1.222417
# 4             NaN
# 5        0.027688
# 6        0.357383
# 7        0.379487
# 8       10.781105
# 9      147.170115
# 10    2156.883586
# 11     424.871202
# 12       4.324237
# 13      18.028367
# 14       2.087360
# 15      49.870815
# 16    1604.049198
# 17     992.768354
# 18     392.577247
# 19       0.279903
# 20            NaN
# 21       0.310749
# 22       0.261343
# 23       0.462417
# 24     268.452423
# 25     308.824841
# 26       2.757824
# Name: e_balance, dtype: float64
# ---------------------------------

# %% [markdown]
# **Calculation of "traffic light" based on electron balance**
#
# Returns pandas-Series with traffic light (red/yellow/green) if NA is taking place based on electron balance. Red corresponds to a electron balance below 1 where available electrons for reduction are not sufficient and thus NA is potentially not taking place.

# %%
na_traffic = mbs.sample_NA_traffic(data, verbose=True)
# Out:
# ==============================================================
#  Running function 'sample_NA_traffic()' on data
# ==============================================================
# WARNING: quantities from name list not in data:
# nitrate
# oxygen
# Maybe data not in standardized format. Run 'standardize()' first.
# _________________________________________________________________
# Evaluation if natural attenuation (NA) is ongoing:
# --------------------------------------------------
# Red light: Reduction is limited at 7 out of 26 locations
# Green light: Reduction is limited at 17 out of 26 locations
# Yellow light: No decision possible at 2 out of 26 locations
# ________________________________________________________________

# %% [markdown]
# ### Evaluation of intervention threshold exceedance
#
# **Calculation of total concentration of contaminants/specified group of contaminants**
#
# Returns pandas-Series with total concentrations of contaminants per well in [ug/l]:

# %%
tot_cont = mbs.total_contaminant_concentration(data, verbose=True, contaminant_group='BTEXIIN')
# Out:
# ==============================================================
#  Running function 'total_contaminant_concentration()' on data
# ==============================================================
# ==============================================================
#  Running function 'total_concentration()' on data
# ==============================================================
# Selecting specific group of contaminants:
# B
# T
# E
# X
# I
# I
# N
# Selected set of quantities:
# indane
# naphthalene
# o_xylene
# benzene
# toluene
# ethylbenzene
# indene
# pm_xylene
# ________________________________________________________________
# total_contaminants in [ug/l] is:
# 1        66.0
# 2       116.0
# 3      4101.0
# 4      9657.0
# 5      7839.0
# 6      5449.0
# 7      2822.0
# 8      1595.0
# 9       184.0
# 10       24.0
# 11       20.0
# 12     8983.0
# 13      498.0
# 14     9224.0
# 15      593.0
# 16       23.0
# 17       31.0
# 18      116.0
# 19     8542.0
# 20    11695.0
# 21     9804.0
# 22     8306.0
# 23    13132.0
# 24      211.1
# 25       18.1
# 26       26.9
# Name: total_contaminants, dtype: float64
# --------------------------------------------------

# %% [markdown]
# **Calculation of "traffic light" for threshold exceedance**
#
# Returns pandas-DataFrame (similar to input data, including well specification) with intervention threshold exceedance analysis:
# * traffic light if well requires intervention (red/yellow/green)
# * number of contaminants exceeding the intervention value
# * list of contaminants above the threshold of intervention

# %%
na_intervention = mbs.thresholds_for_intervention(data,verbose=True,contaminant_group='BTEXIIN')
#na.thresholds_for_intervention?
display(na_intervention)
# Out:
# ==============================================================
#  Running function 'thresholds_for_intervention()' on data
# ==============================================================
# Selecting specific group of contaminants:
# B
# T
# E
# X
# I
# I
# N
# Selected set of quantities:
# indane
# naphthalene
# o_xylene
# benzene
# toluene
# ethylbenzene
# indene
# pm_xylene
# Evaluation of contaminant concentrations exceeding intervention values for BTEXIIN:
# ------------------------------------------------------------------------------------
# Red light: Intervention values exceeded for 16 out of 26 locations
# green light: Concentrations below intervention values at 10 out of 26 locations
# Yellow light: No decision possible at 0 out of 26 locations
# ________________________________________________________________
#     well_type           obs_well      depth     sample_nr  \
# 1   dsn 32 mm        A-32mm-52,5      -52.5  2019-031-001
# 2   dsn 32 mm        A-32mm-65,5      -65.5  2019-031-002
# 3       MLS-1        B-MLS1-3-12        -12  2019-031-009
# 4       MLS-1      B-MLS1-5-15,5      -15.5  2019-031-011
# 5       MLS-1        B-MLS1-6-17        -17  2019-031-012
# 6       MLS-1        B-MLS1-7-19        -19  2019-031-013
# 7       MLS-2      B-MLS2-1-20,5      -20.5  2019-031-014
# 8       MLS-2        B-MLS2-5-28        -28  2019-031-018
# 9       MLS-2        B-MLS2-7-31        -31  2019-031-020
# 10  dsn 32 mm        B-32mm44-45        -45  2019-031-004
# 11  dsn 32 mm       B-32mm-63-64        -64  2019-031-006
# 12      MLS-1        B2-MLS1-1-7         -7  2019-031-029
# 13      MLS-1     B2-MLS1-3-10,5      -10.5  2019-031-031
# 14      MLS-1       B2-MLS1-5-14        -14  2019-031-033
# 15      MLS-1     B2-MLS1-6-15,5      -15.5  2019-031-034
# 16      MLS-2       B2-MLS2-1-20        -20  2019-031-036
# 17      MLS-2       B2-MLS2-4-43        -43  2019-031-039
# 18  dsn 40 mm  B2-32mm-64,5-65,5      -65.5  2019-031-028
# 19      MLS-1      C-MLS1-1-15,5      -15.5  2019-031-048
# 20      MLS-1        C-MLS1-3-19        -19  2019-031-050
# 21      MLS-1        C-MLS1-7-26        -26  2019-031-054
# 22  dsn 32 mm     C-32mm-38,5-39        -39  2019-031-044
# 23  dsn 32 mm     C-32mm-45,5-46        -46  2019-031-047
# 24        NaN                Pb1  14,0-19,0  2019-031-059
# 25        NaN                 60  68,0-72,0  2019-031-062
# 26        NaN              BW205  43,0-45,0  2019-031-063
#
#    intervention_traffic  intervention_number  \
# 1                 green                    0
# 2                 green                    0
# 3                   red                    4
# 4                   red                    6
# 5                   red                    6
# 6                   red                    5
# 7                   red                    7
# 8                   red                    6
# 9                 green                    0
# 10                green                    0
# 11                green                    0
# 12                  red                    7
# 13                  red                    3
# 14                  red                    7
# 15                  red                    2
# 16                green                    0
# 17                green                    0
# 18                green                    0
# 19                  red                    6
# 20                  red                    6
# 21                  red                    7
# 22                  red                    7
# 23                  red                    7
# 24                  red                    1
# 25                green                    0
# 26                green                    0
#
#                             intervention_contaminants
# 1                                                  []
# 2                                                  []
# 3        [indane, naphthalene, benzene, ethylbenzene]
# 4   [indane, naphthalene, o_xylene, benzene, ethyl...
# 5   [indane, naphthalene, o_xylene, benzene, ethyl...
# 6   [indane, naphthalene, benzene, ethylbenzene, p...
# 7   [indane, naphthalene, o_xylene, benzene, ethyl...
# 8   [indane, naphthalene, o_xylene, benzene, ethyl...
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12  [indane, naphthalene, o_xylene, benzene, ethyl...
# 13                       [indane, benzene, pm_xylene]
# 14  [indane, naphthalene, o_xylene, benzene, ethyl...
# 15                             [naphthalene, benzene]
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19  [indane, naphthalene, o_xylene, benzene, ethyl...
# 20  [indane, naphthalene, o_xylene, benzene, ethyl...
# 21  [indane, naphthalene, o_xylene, benzene, ethyl...
# 22  [indane, naphthalene, o_xylene, benzene, ethyl...
# 23  [indane, naphthalene, o_xylene, benzene, ethyl...
# 24                                          [benzene]
# 25                                                 []
# 26                                                 []

# %% [markdown]
# ### Natural Attenuation (NA) Screening in one go
#
# Performing complete NA screening and evaluation of intervention threshold exceedance.
#
# Returns pandas-DataFrame (including well specification from input data) with NA screening results and intervention threshold exceedance analysis:
# * total amount of electron reductors per well in [mmol e-/l]
# * total amount of oxidators per well in [mmol e-/l]
# * electron balance, ratio of reductors to oxidators
# * NA - traffic light (red/yellow/green) if NA is taking place based on electron balance
# * total concentrations of contaminants per well in [ug/l]
# * Intervention traffic light per well (red/yellow/green)
# * number of contaminants exceeding the intervention value
# * list of contaminants above the threshold of intervention

# %%
data_na = mbs.sample_NA_screening(data,verbose = True)
# Out:
# ==============================================================
#  Running function 'sample_NA_screening()' on data
# ==============================================================
# ==============================================================
#  Running function 'reductors()' on data
# ==============================================================
# Selecting specific group of geochemicals:
# O
# N
# S
# Selected set of quantities:
# sulfate
# WARNING: quantities from name list not in data:
# nitrate
# oxygen
# Maybe data not in standardized format. Run 'standardize()' first.
# _________________________________________________________________
# Total amount of electron reductors per well in [mmol e-/l] is:
# 1     16.899063
# 2     13.818939
# 3      1.914672
# 4           NaN
# 5      0.083247
# 6      0.749220
# 7      0.416233
# 8      6.576483
# 9     10.572320
# 10    19.729448
# 11     3.246618
# 12    14.651405
# 13     3.496358
# 14     7.325702
# 15    11.321540
# 16    14.068678
# 17    11.737773
# 18    17.398543
# 19     0.915713
# 20          NaN
# 21     1.165453
# 22     0.832466
# 23     2.330905
# 24    21.798385
# 25     2.131846
# 26     0.028304
# Name: total_reductors, dtype: float64
# ----------------------------------------------------------------
# ==============================================================
#  Running function 'oxidators()' on data
# ==============================================================
# Selecting specific group of contaminants:
# B
# T
# E
# X
# I
# I
# N
# Selected set of quantities:
# indane
# naphthalene
# o_xylene
# benzene
# toluene
# ethylbenzene
# indene
# pm_xylene
# Total amount of oxidators per well in [mmol e-/l] is:
# 1     0.025176
# 2     0.044319
# 3     1.566300
# 4     3.700510
# 5     3.006575
# 6     2.096408
# 7     1.096832
# 8     0.610001
# 9     0.071837
# 10    0.009147
# 11    0.007641
# 12    3.388206
# 13    0.193936
# 14    3.509553
# 15    0.227017
# 16    0.008771
# 17    0.011823
# 18    0.044319
# 19    3.271534
# 20    4.455531
# 21    3.750462
# 22    3.185337
# 23    5.040701
# 24    0.081200
# 25    0.006903
# 26    0.010263
# Name: total_oxidators, dtype: float64
# -----------------------------------------------------
# ==============================================================
#  Running function 'electron_balance()' on data
# ==============================================================
# WARNING: quantities from name list not in data:
# nitrate
# oxygen
# Maybe data not in standardized format. Run 'standardize()' first.
# _________________________________________________________________
# Electron balance e_red/e_cont is:
# 1      671.244878
# 2      311.807766
# 3        1.222417
# 4             NaN
# 5        0.027688
# 6        0.357383
# 7        0.379487
# 8       10.781105
# 9      147.170115
# 10    2156.883586
# 11     424.871202
# 12       4.324237
# 13      18.028367
# 14       2.087360
# 15      49.870815
# 16    1604.049198
# 17     992.768354
# 18     392.577247
# 19       0.279903
# 20            NaN
# 21       0.310749
# 22       0.261343
# 23       0.462417
# 24     268.452423
# 25     308.824841
# 26       2.757824
# Name: e_balance, dtype: float64
# ---------------------------------
# ==============================================================
#  Running function 'sample_NA_traffic()' on data
# ==============================================================
# WARNING: quantities from name list not in data:
# nitrate
# oxygen
# Maybe data not in standardized format. Run 'standardize()' first.
# _________________________________________________________________
# Evaluation if natural attenuation (NA) is ongoing:
# --------------------------------------------------
# Red light: Reduction is limited at 7 out of 26 locations
# Green light: Reduction is limited at 17 out of 26 locations
# Yellow light: No decision possible at 2 out of 26 locations
# ________________________________________________________________

# %%
display(data_na)
# Out:
#     well_type           obs_well      depth     sample_nr  total_reductors  \
# 1   dsn 32 mm        A-32mm-52,5      -52.5  2019-031-001        16.899063
# 2   dsn 32 mm        A-32mm-65,5      -65.5  2019-031-002        13.818939
# 3       MLS-1        B-MLS1-3-12        -12  2019-031-009         1.914672
# 4       MLS-1      B-MLS1-5-15,5      -15.5  2019-031-011              NaN
# 5       MLS-1        B-MLS1-6-17        -17  2019-031-012         0.083247
# 6       MLS-1        B-MLS1-7-19        -19  2019-031-013         0.749220
# 7       MLS-2      B-MLS2-1-20,5      -20.5  2019-031-014         0.416233
# 8       MLS-2        B-MLS2-5-28        -28  2019-031-018         6.576483
# 9       MLS-2        B-MLS2-7-31        -31  2019-031-020        10.572320
# 10  dsn 32 mm        B-32mm44-45        -45  2019-031-004        19.729448
# 11  dsn 32 mm       B-32mm-63-64        -64  2019-031-006         3.246618
# 12      MLS-1        B2-MLS1-1-7         -7  2019-031-029        14.651405
# 13      MLS-1     B2-MLS1-3-10,5      -10.5  2019-031-031         3.496358
# 14      MLS-1       B2-MLS1-5-14        -14  2019-031-033         7.325702
# 15      MLS-1     B2-MLS1-6-15,5      -15.5  2019-031-034        11.321540
# 16      MLS-2       B2-MLS2-1-20        -20  2019-031-036        14.068678
# 17      MLS-2       B2-MLS2-4-43        -43  2019-031-039        11.737773
# 18  dsn 40 mm  B2-32mm-64,5-65,5      -65.5  2019-031-028        17.398543
# 19      MLS-1      C-MLS1-1-15,5      -15.5  2019-031-048         0.915713
# 20      MLS-1        C-MLS1-3-19        -19  2019-031-050              NaN
# 21      MLS-1        C-MLS1-7-26        -26  2019-031-054         1.165453
# 22  dsn 32 mm     C-32mm-38,5-39        -39  2019-031-044         0.832466
# 23  dsn 32 mm     C-32mm-45,5-46        -46  2019-031-047         2.330905
# 24        NaN                Pb1  14,0-19,0  2019-031-059        21.798385
# 25        NaN                 60  68,0-72,0  2019-031-062         2.131846
# 26        NaN              BW205  43,0-45,0  2019-031-063         0.028304
#
#     total_oxidators    e_balance na_traffic_light
# 1          0.025176   671.244878            green
# 2          0.044319   311.807766            green
# 3          1.566300     1.222417            green
# 4          3.700510          NaN                y
# 5          3.006575     0.027688              red
# 6          2.096408     0.357383              red
# 7          1.096832     0.379487              red
# 8          0.610001    10.781105            green
# 9          0.071837   147.170115            green
# 10         0.009147  2156.883586            green
# 11         0.007641   424.871202            green
# 12         3.388206     4.324237            green
# 13         0.193936    18.028367            green
# 14         3.509553     2.087360            green
# 15         0.227017    49.870815            green
# 16         0.008771  1604.049198            green
# 17         0.011823   992.768354            green
# 18         0.044319   392.577247            green
# 19         3.271534     0.279903              red
# 20         4.455531          NaN                y
# 21         3.750462     0.310749              red
# 22         3.185337     0.261343              red
# 23         5.040701     0.462417              red
# 24         0.081200   268.452423            green
# 25         0.006903   308.824841            green
# 26         0.010263     2.757824            green

# %% [markdown]
# ### Activity plot
#
# Create activity plot linking contaminant concentration to metabolite occurence based on NA screening

# %%
### run full NA screening with results added to data

mbs.sample_NA_screening(data, include=True)
mbs.total_contaminant_concentration(data, include=True, contaminant_group='BTEXIIN')

fig, ax = mbs.activity(data)#,save_fig='grift_NA_activity.png',dpi = 300)
# Out:
# WARNING: quantities from name list not in data:
# nitrate
# oxygen
# Maybe data not in standardized format. Run 'standardize()' first.
# _________________________________________________________________
