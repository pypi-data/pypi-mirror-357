# %%
import pandas as pd
import datetime
import numpy as np
from pathlib import Path
import sys
import os
import sys
sys.path.append("../../src/")
import micromet

# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %%
root = Path(r"G:\Shared drives\UGS_Flux\Data_Downloads")  # <── your top-level directory here
#micromet.fix_all_in_parent(root,"21311_Flux_AmeriFluxFormat_*.dat")  # recurse=True if sub-sub-folders exist
# Out:
# ✔ All possible files have been checked.
# defaultdict(list,
#             {'21311_Flux_AmeriFluxFormat_0.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231121/21311_Flux_AmeriFluxFormat_0.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231023/21311_Flux_AmeriFluxFormat_0.dat')],
#              '21311_Flux_AmeriFluxFormat_1.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231121/21311_Flux_AmeriFluxFormat_1.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231023/21311_Flux_AmeriFluxFormat_1.dat')],
#              '21311_Flux_AmeriFluxFormat_2.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231121/21311_Flux_AmeriFluxFormat_2.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231023/21311_Flux_AmeriFluxFormat_2.dat')],
#              '21311_Flux_AmeriFluxFormat_3.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231121/21311_Flux_AmeriFluxFormat_3.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231023/21311_Flux_AmeriFluxFormat_3.dat')],
#              '21311_Flux_AmeriFluxFormat_4.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231121/21311_Flux_AmeriFluxFormat_4.dat')],
#              '21311_Flux_AmeriFluxFormat_5.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20231121/21311_Flux_AmeriFluxFormat_5.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240326/21311_Flux_AmeriFluxFormat_5.dat')],
#              '21311_Flux_AmeriFluxFormat_6.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240326/21311_Flux_AmeriFluxFormat_6.dat')],
#              '21311_Flux_AmeriFluxFormat_7.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240326/21311_Flux_AmeriFluxFormat_7.dat')],
#              '21311_Flux_AmeriFluxFormat_8.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240326/21311_Flux_AmeriFluxFormat_8.dat')],
#              '21311_Flux_AmeriFluxFormat_9.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240326/21311_Flux_AmeriFluxFormat_9.dat')],
#              '21311_Flux_AmeriFluxFormat_10.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240326/21311_Flux_AmeriFluxFormat_10.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240801/21311_Flux_AmeriFluxFormat_10.dat')],
#              '21311_Flux_AmeriFluxFormat_15.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240905/21311_Flux_AmeriFluxFormat_15.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240801/21311_Flux_AmeriFluxFormat_15.dat')],
#              '21311_Flux_AmeriFluxFormat_16.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240905/21311_Flux_AmeriFluxFormat_16.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20241104/21311_Flux_AmeriFluxFormat_16.dat')],
#              '21311_Flux_AmeriFluxFormat_11.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240801/21311_Flux_AmeriFluxFormat_11.dat')],
#              '21311_Flux_AmeriFluxFormat_12.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240801/21311_Flux_AmeriFluxFormat_12.dat')],
#              '21311_Flux_AmeriFluxFormat_13.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240801/21311_Flux_AmeriFluxFormat_13.dat')],
#              '21311_Flux_AmeriFluxFormat_14.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20240801/21311_Flux_AmeriFluxFormat_14.dat')],
#              '21311_Flux_AmeriFluxFormat_18.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20241104/21311_Flux_AmeriFluxFormat_18.dat')],
#              '21311_Flux_AmeriFluxFormat_17.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20241104/21311_Flux_AmeriFluxFormat_17.dat')],
#              '21311_Flux_AmeriFluxFormat_19.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20241211/21311_Flux_AmeriFluxFormat_19.dat')],
#              '21311_Flux_AmeriFluxFormat_21.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20241211/21311_Flux_AmeriFluxFormat_21.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20250207/21311_Flux_AmeriFluxFormat_21.dat')],
#              '21311_Flux_AmeriFluxFormat_20.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20241211/21311_Flux_AmeriFluxFormat_20.dat')],
#              '21311_Flux_AmeriFluxFormat_22.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20250207/21311_Flux_AmeriFluxFormat_22.dat')],
#              '21311_Flux_AmeriFluxFormat_23.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20250207/21311_Flux_AmeriFluxFormat_23.dat')],
#              '21311_Flux_AmeriFluxFormat_24.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20250207/21311_Flux_AmeriFluxFormat_24.dat')],
#              '21311_Flux_AmeriFluxFormat_28.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/E20250603/21311_Flux_AmeriFluxFormat_28.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20250207/E20250603/21311_Flux_AmeriFluxFormat_28.dat')],
#              '21311_Flux_AmeriFluxFormat_29.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/E20250603/21311_Flux_AmeriFluxFormat_29.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20250207/E20250603/21311_Flux_AmeriFluxFormat_29.dat')],
#              '21311_Flux_AmeriFluxFormat_27.dat': [WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/E20250603/21311_Flux_AmeriFluxFormat_27.dat'),
#               WindowsPath('G:/Shared drives/UGS_Flux/Data_Downloads/Desert_View_Myton/e20250207/E20250603/21311_Flux_AmeriFluxFormat_27.dat')]})

# %%
root = Path(r"G:\Shared drives\UGS_Flux\Data_Downloads")  # <── your top-level directory here
proc = micromet.AmerifluxDataProcessor(logger=logger)


datatype = "eddy"  # or "met"

site_folders = {
    #"US-UTD": "Dugout_Ranch",
    #"US-UTB": "BSF",
    #"US-UTJ": "Bluff",
    #"US-UTW": "Wellington",
    #"US-UTE": "Escalante",
    #"US-UTM": "Matheson",
    #"US-UTP": "Phrag",
    #"US-CdM": "Cedar_mesa",
    #"US-UTV": "Desert_View_Myton",
    #"US-UTN": "Juab",
    "US-UTG": "Green_River",
}
data = {}
for stationid, folder in site_folders.items():
    if datatype == "met":
        search_str = f"*Statistics_Ameriflux*.dat"
    else:
        search_str = f"*AmeriFluxFormat_*.dat"
    df = proc.raw_file_compile(stationid, root / folder, search_str)
    df.to_parquet(root / f"{stationid}_{datatype}_{df['file_no'].min()}_{df['file_no'].max()}_data.parquet",)
# Out:
# 2025-06-23 17:10:35,479 - INFO - Compiling data from G:\Shared drives\UGS_Flux\Data_Downloads\Green_River
# 2025-06-23 17:10:35,491 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_4.dat
# 2025-06-23 17:10:36,250 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_2.dat
# 2025-06-23 17:10:36,993 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_0.dat
# 2025-06-23 17:10:37,638 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_3.dat
# 2025-06-23 17:10:38,228 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_1.dat
# 2025-06-23 17:10:38,784 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_6.dat
# 2025-06-23 17:10:40,352 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_5.dat
# 2025-06-23 17:10:41,793 - INFO - Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Green_River\e20250512\25415_Flux_AmeriFluxFormat_7.dat

# %%
df
# Out:
#       TIMESTAMP_START  TIMESTAMP_END       CO2  CO2_SIGMA       H2O  \
# 0        202503241645   202503241800       NaN        NaN       NaN
# 1        202503241800   202503241830       NaN        NaN       NaN
# 2        202503241830   202503250230       NaN        NaN       NaN
# 3        202503250230   202503250300       NaN        NaN       NaN
# 4        202503250300   202503250830  436.9250  14.502410  6.930443
# ...               ...            ...       ...        ...       ...
# 2410     202505121000   202505121030  431.9309   0.650161  5.480564
# 2411     202505121030   202505121100  432.0706   0.703489  5.527364
# 2412     202505121100   202505121130  432.0311   0.814261  5.704107
# 2413     202505121130   202505121200  432.3903   0.838913  5.304916
# 2414     202505121200   202505121230  432.5565   2.447572  5.207652
#
#       H2O_SIGMA         FC  FC_SSITC_TEST         LE  LE_SSITC_TEST  ...  \
# 0           NaN        NaN            NaN        NaN            NaN  ...
# 1           NaN        NaN            NaN        NaN            NaN  ...
# 2           NaN        NaN            NaN        NaN            NaN  ...
# 3           NaN        NaN            NaN        NaN            NaN  ...
# 4      0.051864  27.137040            1.0   8.988438            1.0  ...
# ...         ...        ...            ...        ...            ...  ...
# 2410   0.230537  -0.023363            1.0  51.270590            1.0  ...
# 2411   0.200343  -0.142949            1.0  52.767020            1.0  ...
# 2412   0.328159  -0.599764            1.0  65.230580            2.0  ...
# 2413   0.152339  -0.104204            1.0  44.586330            1.0  ...
# 2414   0.194126   1.849401            1.0  68.280190            1.0  ...
#
#       SWC_1_1_2        ALB  NETRAD       SW_IN     SW_OUT  LW_IN  LW_OUT    P  \
# 0           NaN  12.223920     NaN   71.158350  16.038200    NaN     NaN  0.0
# 1           NaN   9.075713     NaN   -3.296395  -0.480597    NaN     NaN  0.0
# 2           NaN   0.000000     NaN  -21.556910  -4.438842    NaN     NaN  0.0
# 3           NaN   0.000000     NaN  -22.233140  -4.507426    NaN     NaN  0.0
# 4           NaN  14.671550     NaN  188.273300  56.273500    NaN     NaN  0.0
# ...         ...        ...     ...         ...        ...    ...     ...  ...
# 2410        NaN   0.000000     NaN -121.209000  49.243050    NaN     NaN  0.0
# 2411        NaN   0.000000     NaN -123.271200  55.322760    NaN     NaN  0.0
# 2412        NaN   0.000000     NaN -122.943100  58.552380    NaN     NaN  0.0
# 2413        NaN   0.000000     NaN -123.862800  59.496240    NaN     NaN  0.0
# 2414        NaN   1.966987     NaN  -15.664430  77.269750    NaN     NaN  0.0
#
#       file_no  datalogger_no
# 0           4          25415
# 1           4          25415
# 2           4          25415
# 3           4          25415
# 4           4          25415
# ...       ...            ...
# 2410        7          25415
# 2411        7          25415
# 2412        7          25415
# 2413        7          25415
# 2414        7          25415
#
# [2415 rows x 62 columns]

# %%
# Process data for all stations
site_folders = {#'US-UTD':'Dugout_Ranch',
                'US-UTB':'BSF',
                'US-UTJ':'Bluff',
                'US-UTW':'Wellington',
                'US-UTE':'Escalante',
                'US-UTM':'Matheson',
                'US-UTP':'Phrag',
                'US-CdM':'Cedar_Mesa',
                'US-UTV':'Desert_View_Myton',
                'US-UTL':'Pelican_Lake',
                'US-UTG':'Green_River',
                }


loggertype = 'eddy'
station = 'US-UTE'
station_id = manager.get_station_id(station)
manager = micromet.StationDataProcessor(config=config, 
                                        engine=engine)
last_date = manager.get_max_date(station)
raw_data, pack_size, status_code = manager.download_from_station(station,
                                                                 loggertype=loggertype,
                                                                 p1=f"{pd.to_datetime(last_date, format="%Y%m%d%H%M"):%Y-%m-%d %H:%M}",
                                                                )

manager.process_station_data(site_folders,
                             config_path = "../../src/micromet/data/reformatter_vars.yml",
                             var_limits_csv = "../../src/micromet/data/extreme_values.csv",       
                             )
